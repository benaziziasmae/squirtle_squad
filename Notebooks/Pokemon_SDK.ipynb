# %%
from pokemontcgsdk import Card
from pokemontcgsdk import Set
from pokemontcgsdk import Type
from pokemontcgsdk import Supertype
from pokemontcgsdk import Subtype
from pokemontcgsdk import Rarity
from config import api_key

# %%
from pokemontcgsdk import RestClient

RestClient.configure('12345678-1234-1234-1234-123456789ABC')

# %%
cards = Card.all()

# %%
cards
# Out:
# [Card(abilities=[Ability(name='Damage Bind', text="Each Pokémon that has any damage counters on it (both yours and your opponent's) can't use any Poké-Powers.", type='Poké-Body')], artist='Atsuko Nishida', ancientTrait=None, attacks=[Attack(name='Gigavolt', cost=['Lightning', 'Colorless'], convertedEnergyCost=2, damage='30+', text='Flip a coin. If heads, this attack does 30 damage plus 30 more damage. If tails, the Defending Pokémon is now Paralyzed.'), Attack(name='Reflect Energy', cost=['Lightning', 'Colorless', 'Colorless'], convertedEnergyCost=3, damage='70', text='Move an Energy card attached to Ampharos to 1 of your Benched Pokémon.')], convertedRetreatCost=2, evolvesFrom='Flaaffy', flavorText=None, hp='130', id='pl1-1', images=CardImage(small='https://images.pokemontcg.io/pl1/1.png', large='https://images.pokemontcg.io/pl1/1_hires.png'), legalities=Legality(unlimited='Legal', expanded=None, standard=None), name='Ampharos', nationalPokedexNumbers=[181], number='1', rarity='Rare
# ...

# %%
cards.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e4dec03b5b52> in <module>
# ----> 1 cards.type()
#
# AttributeError: 'list' object has no attribute 'type'

# %%
import json
jsonString = json.dumps(cards)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-321748014a53> in <module>
#       1 import json
# ----> 2 jsonString = json.dumps(cards)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# ...

# %%
import jsonpickle
from json import JSONEncoder

# %%
encoded_card = jsonpickle.encode(cards)

# %%
jsonString = json.dump(cards)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ff1fe765ab59> in <module>
# ----> 1 jsonString = json.dump(cards)
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
jsonString = json.dump(cards, fp, *, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)
# Out:
#   File "<ipython-input-21-a7e61caf1376>", line 1
#     jsonString = json.dump(cards, fp, *, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)
#                                        ^
# SyntaxError: invalid syntax
